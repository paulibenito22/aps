# %% [markdown]
# ### Análisis y Procesamiento de Señales
# # Trabajo Práctico N°0
# ### Paulina Benito

# %% [markdown]
# En el siguiente informe se muestrarán los rersultados de la experiencia correspondiente a la TS0.

# %% [markdown]
# Como primer paso importo las librerias necesarias para las funciones del código.

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# Luego hago una serie de definiciones, entre ellas la función a generar y sus parámetros corrspondientes.

# %%
def mi_funcion_sen( vmax , dc, ff , ph, nn,  fs) : 
    xx = dc + vmax * np.sin(2*np.pi*ff*tt + ph)
    return (tt,xx)

N= 1000 #Hz
fs= 1000 #Muestras 
ts= 1/fs 
ph=0
nn=N   
vmax = 1.5
dc= 0

# %% [markdown]
# A continuación se irá modificando las frecuencias para poder estudiar el comportamiento de la señal.

# %%
ff= 3
tt=np.arange(0,nn) *ts 
tt, xx = mi_funcion_sen( vmax , dc , ff , ph, nn,  fs)

#Gráfcio
plt.figure()
plt.plot(tt, xx)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# El gráfico representa una señal senoidal con amplitud de 1,5 y frecuencia de 3Hz como fuero definidas previamente.

# %% [markdown]
# Ahora modifico la frecuencia.

# %%
ff2 = 100
tt2, xx2 = mi_funcion_sen(vmax, dc, ff2, ph, nn, fs)

#Gráfico 2
plt.figure()
plt.plot(tt2, xx2)
plt.show()

# %%
El gráfico se ve más denso porque al aumentar la frecuencia de la señal entran más períodos en el mismo segundo.

# %%
ff3 = 500
tt3, xx3 = mi_funcion_sen(vmax, dc, ff3, ph, nn, fs)
                                  
plt.figure()
plt.plot(tt3, xx3)
plt.show()

# %% [markdown]
# Como la frecuencia de muestreo es fs=1000Hz, al implementar una frecuencia de 500Hz estanos tomando el valor exacto de Nyquist (fs/2). Esto indica que las muestras deberían ser 0. Por ende, este gráfico no muestra una señal sino que errores computacional.

# %%
ff4 = 999
tt4, xx4 = mi_funcion_sen(vmax, dc, ff4, ph, nn, fs)
#Gráfico 4
plt.figure()
plt.plot(tt4, xx4)
plt.show()

# %% [markdown]
# Como ahora la frecuencia es 999Hz, es decir, 1 Hz menos que la fs, no se cumple la condición de Nyquist y aparece el aliasing. El gráfico muestra una señal senoidal de 1 Hz invertida en fase debido a que 999 Hz es equivalente a 1000-1 Hz respecto a la frecuencia de muestreo.

# %%
ff5=1001
tt5, xx5 = mi_funcion_sen(vmax, dc, ff5 , ph, nn, fs)
#Gráfico 5                                
plt.figure()
plt.plot(tt5,xx5)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
En este caso pasa algo parecido al anterior pero con fase invertida debido a que las muestras son equivalentes a las de una señal de 1Hz debido al aliasing.

# %%
ff6=2001
tt6, xx6 = mi_funcion_sen(vmax, dc, ff6 , ph, nn, fs)
#Gráfico 6                                
plt.figure()
plt.plot(tt6,xx6)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Al igual que en los casos de 999 Hz y 1001 Hz, acá también aparece aliasing porque no se cumple Nyquist. La diferencia es que 2001 Hz equivale a 2fs+1, por lo que las muestras vuelven a comportarse como una señal aparente de 1 Hz.
